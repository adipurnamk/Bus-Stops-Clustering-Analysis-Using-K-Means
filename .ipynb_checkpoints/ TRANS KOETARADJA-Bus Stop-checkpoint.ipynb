# %%
import tabula

# %% [markdown]
# there is 4 pages in the pdf file, use for loop to extract it to list

# %%
list = []
for i in range(1, 5) :
    j = str(i)
    pdf = tabula.io.read_pdf('Halte Trans Koetaradja.pdf', pages=j, stream=True, output_format='dataframe')
    list.append(pdf)

# %% [markdown]
# the result is list of list of dataframe

# %%
len(list)
# Out:
# 4

# %% [markdown]
# # Cleaning process

# %% [markdown]
# Every dataframe is using diferent table standard, so every dataframes will be treated differently

# %%
# import pandas library
import pandas as pd

# %% [markdown]
# ## Table from page 1

# %%
# extracting table from page 1
corr1 = pd.DataFrame(list[0][0])

# %%
# Each page represent each corridor, so we add corridor identifier after index
# Corridor 1 : City Center-Darussalam Route
corr1.insert(0, 'Corridor', 1)
corr1
# Out:
#     Corridor  NO                         Unnamed: 1  NAMA  \
# 0          1   1                       HALTE KEUDAH   NaN
# 1          1   2         HALTE PORTABLE MASJID RAYA   NaN
# 2          1   3                     HALTE SP. LIMA   NaN
# 3          1   4                 HALTE KP. KEURAMAT   NaN
# 4          1   5      HALTE PORTABLE SP. JAMBO TAPE   NaN
# 5          1   6                        HALTE RSUZA   NaN
# 6          1   7             HALTE KANTOR GUB. ACEH   NaN
# 7          1   8                       HALTE LINGKE   NaN
# 8          1   9           HALTE PORTABLE SP. MESRA   NaN
# 9          1  10            HALTE PORTABLE LAMNYONG   NaN
# 10         1  11              HALTE FAKULTAS TEKNIK   NaN
# 11         1  12          HALTE FAKULTAS KEDOKTERAN   NaN
# 12         1  13  HALTE PORTABLE FAKULTAS PERTANIAN   NaN
# 13         1  14                 HALTE MASJID JAMI'   NaN
# 14         1  15            HALTE PORTABLE SMA LIMA   NaN
# 15         1  16                     HALTE LAMNYONG   NaN
# 16         1  17                    HALTE SP. MESRA   NaN
# 17         1  18                        HALTE PRADA   NaN
# 18         1  19                         HALTE DPKA   NaN
# 19         1  20                        HALTE RSUZA   NaN
# 20         1  21          HALTE PORTABLE JAMBO TAPE   NaN
# 21         1  22                 HALTE KP. KEURAMAT   NaN
# 22         1  23            HALTE PORTABLE SP. LIMA   NaN
# 23         1  24                    HALTE PEUNAYONG   NaN
# 24         1  25     HALTE PORTABLE EKONOMI UNSYIAH   NaN
# 25         1  26           HALTE PORTABLE BEURABONG   NaN
#
#               KOORDINAT TAHUN PEMBANGUNAN
# 0   5.559781, 95.317649         APBA 2015
# 1   5.553979, 95.318540         APBA 2015
# 2   5.556597, 95.323211         APBA 2015
# 3   5.558210, 95.327378         APBA 2015
# 4   5.559729, 95.330911         APBA 2015
# 5   5.565763, 95.337352         APBA 2015
# 6   5.571251, 95.342931         APBA 2015
# 7   5.575517, 95.347320         APBA 2015
# 8   5.580420, 95.353206         APBA 2015
# 9   5.575038, 95.355430         APBA 2015
# 10  5.566064, 95.366778         APBA 2015
# 11  5.564918, 95.372027         APBA 2015
# 12  5.566133, 95.371822         APBA 2015
# 13  5.571456, 95.371424         APBA 2015
# 14  5.574906, 95.367055         APBA 2015
# 15  5.575536, 95.355065         APBA 2015
# 16  5.579951, 95.352974         APBA 2015
# 17  5.573958, 95.345972         APBA 2015
# 18  5.570738, 95.342698         APBA 2015
# 19  5.564713, 95.336554         APBA 2015
# 20  5.559908, 95.331420         APBA 2015
# 21  5.557950, 95.327167         APBA 2015
# 22  5.556219, 95.322956         APBA 2015
# 23  5.558637, 95.318945         APBA 2015
# 24  5.573954, 95.365612         APBA 2017
# 25  5.568054, 95.377066         APBA 2017

# %%
# Remove unused column
corr1.drop(columns=['NO', 'NAMA', 'TAHUN PEMBANGUNAN'], inplace=True)
corr1.head()

# Rename non the rest
corr1.rename(columns={'Unnamed: 1' : 'Name', 'KOORDINAT' : 'Coordinates' }, inplace=True)
corr1
# Out:
#     Corridor                               Name          Coordinates
# 0          1                       HALTE KEUDAH  5.559781, 95.317649
# 1          1         HALTE PORTABLE MASJID RAYA  5.553979, 95.318540
# 2          1                     HALTE SP. LIMA  5.556597, 95.323211
# 3          1                 HALTE KP. KEURAMAT  5.558210, 95.327378
# 4          1      HALTE PORTABLE SP. JAMBO TAPE  5.559729, 95.330911
# 5          1                        HALTE RSUZA  5.565763, 95.337352
# 6          1             HALTE KANTOR GUB. ACEH  5.571251, 95.342931
# 7          1                       HALTE LINGKE  5.575517, 95.347320
# 8          1           HALTE PORTABLE SP. MESRA  5.580420, 95.353206
# 9          1            HALTE PORTABLE LAMNYONG  5.575038, 95.355430
# 10         1              HALTE FAKULTAS TEKNIK  5.566064, 95.366778
# 11         1          HALTE FAKULTAS KEDOKTERAN  5.564918, 95.372027
# 12         1  HALTE PORTABLE FAKULTAS PERTANIAN  5.566133, 95.371822
# 13         1                 HALTE MASJID JAMI'  5.571456, 95.371424
# 14         1            HALTE PORTABLE SMA LIMA  5.574906, 95.367055
# 15         1                     HALTE LAMNYONG  5.575536, 95.355065
# 16         1                    HALTE SP. MESRA  5.579951, 95.352974
# 17         1                        HALTE PRADA  5.573958, 95.345972
# 18         1                         HALTE DPKA  5.570738, 95.342698
# 19         1                        HALTE RSUZA  5.564713, 95.336554
# 20         1          HALTE PORTABLE JAMBO TAPE  5.559908, 95.331420
# 21         1                 HALTE KP. KEURAMAT  5.557950, 95.327167
# 22         1            HALTE PORTABLE SP. LIMA  5.556219, 95.322956
# 23         1                    HALTE PEUNAYONG  5.558637, 95.318945
# 24         1     HALTE PORTABLE EKONOMI UNSYIAH  5.573954, 95.365612
# 25         1           HALTE PORTABLE BEURABONG  5.568054, 95.377066

# %%
# Extract latitude and longitude from 'KOORDINAT' column
corr1['Latitude'] = corr1.Coordinates.str[:8]
corr1['Longtude'] = corr1.Coordinates.str[10:]
corr1.head()
# Out:
#    Corridor                           Name          Coordinates  Latitude  \
# 0         1                   HALTE KEUDAH  5.559781, 95.317649  5.559781
# 1         1     HALTE PORTABLE MASJID RAYA  5.553979, 95.318540  5.553979
# 2         1                 HALTE SP. LIMA  5.556597, 95.323211  5.556597
# 3         1             HALTE KP. KEURAMAT  5.558210, 95.327378  5.558210
# 4         1  HALTE PORTABLE SP. JAMBO TAPE  5.559729, 95.330911  5.559729
#
#     Longtude
# 0  95.317649
# 1  95.318540
# 2  95.323211
# 3  95.327378
# 4  95.330911

# %%
# After extracting latitutde and longitude we need no more 'Coordinates' column
# Remove 'Coordinates' column
corr1.drop(columns=['Coordinates'], inplace=True)
corr1
# Out:
#     Corridor                               Name  Latitude   Longtude
# 0          1                       HALTE KEUDAH  5.559781  95.317649
# 1          1         HALTE PORTABLE MASJID RAYA  5.553979  95.318540
# 2          1                     HALTE SP. LIMA  5.556597  95.323211
# 3          1                 HALTE KP. KEURAMAT  5.558210  95.327378
# 4          1      HALTE PORTABLE SP. JAMBO TAPE  5.559729  95.330911
# 5          1                        HALTE RSUZA  5.565763  95.337352
# 6          1             HALTE KANTOR GUB. ACEH  5.571251  95.342931
# 7          1                       HALTE LINGKE  5.575517  95.347320
# 8          1           HALTE PORTABLE SP. MESRA  5.580420  95.353206
# 9          1            HALTE PORTABLE LAMNYONG  5.575038  95.355430
# 10         1              HALTE FAKULTAS TEKNIK  5.566064  95.366778
# 11         1          HALTE FAKULTAS KEDOKTERAN  5.564918  95.372027
# 12         1  HALTE PORTABLE FAKULTAS PERTANIAN  5.566133  95.371822
# 13         1                 HALTE MASJID JAMI'  5.571456  95.371424
# 14         1            HALTE PORTABLE SMA LIMA  5.574906  95.367055
# 15         1                     HALTE LAMNYONG  5.575536  95.355065
# 16         1                    HALTE SP. MESRA  5.579951  95.352974
# 17         1                        HALTE PRADA  5.573958  95.345972
# 18         1                         HALTE DPKA  5.570738  95.342698
# 19         1                        HALTE RSUZA  5.564713  95.336554
# 20         1          HALTE PORTABLE JAMBO TAPE  5.559908  95.331420
# 21         1                 HALTE KP. KEURAMAT  5.557950  95.327167
# 22         1            HALTE PORTABLE SP. LIMA  5.556219  95.322956
# 23         1                    HALTE PEUNAYONG  5.558637  95.318945
# 24         1     HALTE PORTABLE EKONOMI UNSYIAH  5.573954  95.365612
# 25         1           HALTE PORTABLE BEURABONG  5.568054  95.377066

# %%
# Check NaN value
corr1[corr1.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Corridor, Name, Latitude, Longtude]
# Index: []

# %% [markdown]
# ## Table 2

# %%
# extracting dataframe
corr2 = pd.DataFrame(list[1][0])

# %%
# Corridor 2 : City Center-Blang Bintang Route
corr2.insert(0, 'Corridor', 2)
corr2
# Out:
#     Corridor  NO                                              NAMA  \
# 0          2   1                 HALTE PELABUHAN ULEE LHEUE TIPE A
# 1          2   2                 HALTE KUBURAN MASSAL 1 ULEE LHEUE
# 2          2   3     HALTE KUBURAN MASSAL 2  ULEE LHEUE (seberang)
# 3          2   4              HALTE PUNGE 1 (Seberang kantor WIKA)
# 4          2   5                             HALTE PASAR ACEH BARU
# 5          2   6                    HALTE MASJID RAYA BAITURRAHMAN
# 6          2   7        HALTE Sp. SURABAYA  1 (depan Dunia Barusa)
# 7          2   8           HALTE Sp. SURABAYA  2 (depan Wong Solo)
# 8          2   9                   HALTE Sp. BATOH 1 (Simpang AMD)
# 9          2  10           HALTE Sp. BATOH 2 (seberang SPBU BATOH)
# 10         2  11                      HALTE DEPAN TERMINAL BATOH 1
# 11         2  12           HALTE DEPAN TERMINAL BATOH 2 (seberang)
# 12         2  13   HALTE DARUL IMARAH 1 (Depan SMA 1 DARUL IMARAH)
# 13         2  14           HALTE DARUL IMARAH 2 (Sp. LAMPEUNEURUT)
# 14         2  15                    HALTE SIRON 1 (DEPAN SD SIRON)
# 15         2  16           HALTE SIRON  2 (DEPAN CLINIC PMI SIRON)
# 16         2  17                       HALTE GANI 1 DEPAN SD GANI)
# 17         2  18                  HALTE GANI  2 (DEPAN PUSTU GANI)
# 18         2  19              HALTE BLANG BINTANG 1 (depan Masjid)
# 19         2  20            HALTE BLANG BINTANG 2 (bundaran LANUD)
# 20         2  21                                      HALTE BARATA
# 21         2  22                              HALTE MUSEUM TSUNAMI
# 22         2  23             HALTE PORTABLE PELABUHAN ULEE LHEUE 1
# 23         2  24             HALTE PORTABLE PELABUHAN ULEE LHEUE 2
# 24         2  25  HALTE PORTABLE DEPAN TAMAN REKREASI ULEE LHEUE 1
# 25         2  26  HALTE PORTABLE DEPAN TAMAN REKREASI ULEE LHEUE 2
# 26         2  27                   HALTE PORTABLE DEPAN SMA 1 BLPD
# 27         2  28                        HALTE PORTABLE MESJID RAYA
# 28         2  29                      HALTE PORTABLE KFC SIMPANG 5
# 29         2  30                   HALTE PORTABLE SMA 3 JAMBO TAPE
# 30         2  31              HALTE PORTABLE SIMPANG MESRA KTR POS
# 31         2  32           HALTE PORTABLE PUSTAKA WILAYAH LAMNYONG
# 32         2  33                 HALTE PORTABLE LAB SCHOOL UNSYIAH
# 33         2  34                      HALTE LAMBARO (DEPAN YAMAHA)
# 34         2  35                 HALTE PUNGE 2 (DEPAN KANTOR WIKA)
#
#               KOORDINAT TAHUN PEMBANGUNAN
# 0   5.564047, 95.292068         APBA 2016
# 1   5.555766, 95.285874         APBA 2016
# 2   5.555576, 95.285798         APBA 2016
# 3   5.550702, 95.306764         APBA 2016
# 4   5.555505, 95.316060         APBA 2016
# 5   5.554093, 95.318361         APBA 2016
# 6   5.542107, 95.330246         APBA 2016
# 7   5.547179, 95.330122         APBA 2016
# 8   5.534133, 95.330384         APBA 2016
# 9   5.535071, 95.330133         APBA 2016
# 10  5.529697, 95.330137         APBA 2016
# 11  5.529722, 95.330331         APBA 2016
# 12  5.514488, 95.331001         APBA 2016
# 13  5.514853, 95.330035         APBA 2016
# 14  5.511284, 95.362883         APBA 2016
# 15  5.511184, 95.363218         APBA 2016
# 16  5.513257, 95.380454         APBA 2016
# 17  5.513257, 95.380454         APBA 2016
# 18  5.510991, 95.413920         APBA 2016
# 19  5.510519, 95.414005         APBA 2016
# 20  5.552143, 95.318819         APBA 2016
# 21  5.548495, 95.314140         APBA 2016
# 22                  NaN         APBA 2016
# 23                  NaN         APBA 2016
# 24                  NaN         APBA 2016
# 25                  NaN         APBA 2016
# 26  5.552408, 95.312943         APBA 2016
# 27                  NaN         APBA 2016
# 28                  NaN         APBA 2016
# 29                  NaN         APBA 2016
# 30                  NaN         APBA 2016
# 31                  NaN         APBA 2016
# 32  5.574398, 95.365406         APBA 2016
# 33  5.507380, 95.356315         APBA 2017
# 34  5.550533, 95.306570         APBA 2017

# %%
# Remove unused column
corr2.drop(columns=['NO', 'TAHUN PEMBANGUNAN'], axis=1, inplace=True)

# Rename the rest
corr2.rename(columns={'NAMA' : 'Name', 'KOORDINAT' : 'Coordinates' }, inplace=True)
corr2.head()
# Out:
#    Corridor                                           Name  \
# 0         2              HALTE PELABUHAN ULEE LHEUE TIPE A
# 1         2              HALTE KUBURAN MASSAL 1 ULEE LHEUE
# 2         2  HALTE KUBURAN MASSAL 2  ULEE LHEUE (seberang)
# 3         2           HALTE PUNGE 1 (Seberang kantor WIKA)
# 4         2                          HALTE PASAR ACEH BARU
#
#            Coordinates
# 0  5.564047, 95.292068
# 1  5.555766, 95.285874
# 2  5.555576, 95.285798
# 3  5.550702, 95.306764
# 4  5.555505, 95.316060

# %%
# Extract latitude and longitude
corr2['Latitude'] = corr2.Coordinates.str[:8]
corr2['Longtude'] = corr2.Coordinates.str[10:]
corr2.head()
# Out:
#    Corridor                                           Name  \
# 0         2              HALTE PELABUHAN ULEE LHEUE TIPE A
# 1         2              HALTE KUBURAN MASSAL 1 ULEE LHEUE
# 2         2  HALTE KUBURAN MASSAL 2  ULEE LHEUE (seberang)
# 3         2           HALTE PUNGE 1 (Seberang kantor WIKA)
# 4         2                          HALTE PASAR ACEH BARU
#
#            Coordinates  Latitude   Longtude
# 0  5.564047, 95.292068  5.564047  95.292068
# 1  5.555766, 95.285874  5.555766  95.285874
# 2  5.555576, 95.285798  5.555576  95.285798
# 3  5.550702, 95.306764  5.550702  95.306764
# 4  5.555505, 95.316060  5.555505  95.316060

# %%
# Remove KOORDINAT column
corr2.drop(columns=['Coordinates'], inplace=True)
corr2
# Out:
#     Corridor                                              Name  Latitude  \
# 0          2                 HALTE PELABUHAN ULEE LHEUE TIPE A  5.564047
# 1          2                 HALTE KUBURAN MASSAL 1 ULEE LHEUE  5.555766
# 2          2     HALTE KUBURAN MASSAL 2  ULEE LHEUE (seberang)  5.555576
# 3          2              HALTE PUNGE 1 (Seberang kantor WIKA)  5.550702
# 4          2                             HALTE PASAR ACEH BARU  5.555505
# 5          2                    HALTE MASJID RAYA BAITURRAHMAN  5.554093
# 6          2        HALTE Sp. SURABAYA  1 (depan Dunia Barusa)  5.542107
# 7          2           HALTE Sp. SURABAYA  2 (depan Wong Solo)  5.547179
# 8          2                   HALTE Sp. BATOH 1 (Simpang AMD)  5.534133
# 9          2           HALTE Sp. BATOH 2 (seberang SPBU BATOH)  5.535071
# 10         2                      HALTE DEPAN TERMINAL BATOH 1  5.529697
# 11         2           HALTE DEPAN TERMINAL BATOH 2 (seberang)  5.529722
# 12         2   HALTE DARUL IMARAH 1 (Depan SMA 1 DARUL IMARAH)  5.514488
# 13         2           HALTE DARUL IMARAH 2 (Sp. LAMPEUNEURUT)  5.514853
# 14         2                    HALTE SIRON 1 (DEPAN SD SIRON)  5.511284
# 15         2           HALTE SIRON  2 (DEPAN CLINIC PMI SIRON)  5.511184
# 16         2                       HALTE GANI 1 DEPAN SD GANI)  5.513257
# 17         2                  HALTE GANI  2 (DEPAN PUSTU GANI)  5.513257
# 18         2              HALTE BLANG BINTANG 1 (depan Masjid)  5.510991
# 19         2            HALTE BLANG BINTANG 2 (bundaran LANUD)  5.510519
# 20         2                                      HALTE BARATA  5.552143
# 21         2                              HALTE MUSEUM TSUNAMI  5.548495
# 22         2             HALTE PORTABLE PELABUHAN ULEE LHEUE 1       NaN
# 23         2             HALTE PORTABLE PELABUHAN ULEE LHEUE 2       NaN
# 24         2  HALTE PORTABLE DEPAN TAMAN REKREASI ULEE LHEUE 1       NaN
# 25         2  HALTE PORTABLE DEPAN TAMAN REKREASI ULEE LHEUE 2       NaN
# 26         2                   HALTE PORTABLE DEPAN SMA 1 BLPD  5.552408
# 27         2                        HALTE PORTABLE MESJID RAYA       NaN
# 28         2                      HALTE PORTABLE KFC SIMPANG 5       NaN
# 29         2                   HALTE PORTABLE SMA 3 JAMBO TAPE       NaN
# 30         2              HALTE PORTABLE SIMPANG MESRA KTR POS       NaN
# 31         2           HALTE PORTABLE PUSTAKA WILAYAH LAMNYONG       NaN
# 32         2                 HALTE PORTABLE LAB SCHOOL UNSYIAH  5.574398
# 33         2                      HALTE LAMBARO (DEPAN YAMAHA)  5.507380
# 34         2                 HALTE PUNGE 2 (DEPAN KANTOR WIKA)  5.550533
#
#      Longtude
# 0   95.292068
# 1   95.285874
# 2   95.285798
# 3   95.306764
# 4   95.316060
# 5   95.318361
# 6   95.330246
# 7   95.330122
# 8   95.330384
# 9   95.330133
# 10  95.330137
# 11  95.330331
# 12  95.331001
# 13  95.330035
# 14  95.362883
# 15  95.363218
# 16  95.380454
# 17  95.380454
# 18  95.413920
# 19  95.414005
# 20  95.318819
# 21  95.314140
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26  95.312943
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32  95.365406
# 33  95.356315
# 34  95.306570

# %%
# Check NaN value
corr2[corr2.isna().any(axis=1)]
# Out:
#     Corridor                                              Name Latitude  \
# 22         2             HALTE PORTABLE PELABUHAN ULEE LHEUE 1      NaN
# 23         2             HALTE PORTABLE PELABUHAN ULEE LHEUE 2      NaN
# 24         2  HALTE PORTABLE DEPAN TAMAN REKREASI ULEE LHEUE 1      NaN
# 25         2  HALTE PORTABLE DEPAN TAMAN REKREASI ULEE LHEUE 2      NaN
# 27         2                        HALTE PORTABLE MESJID RAYA      NaN
# 28         2                      HALTE PORTABLE KFC SIMPANG 5      NaN
# 29         2                   HALTE PORTABLE SMA 3 JAMBO TAPE      NaN
# 30         2              HALTE PORTABLE SIMPANG MESRA KTR POS      NaN
# 31         2           HALTE PORTABLE PUSTAKA WILAYAH LAMNYONG      NaN
#
#    Longtude
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN

# %% [markdown]
# ## Table 3

# %%
# extracting table
corr3 = pd.DataFrame(list[2][0])

# Corridor 3 : City Center-Mata Ie Route
corr3.insert(0, 'Corridor', 3)
corr3
# Out:
#     Corridor Unnamed: 0                                        Unnamed: 1  \
# 0          3         NO                                               NaN
# 1          3        NaN                                               NaN
# 2          3          1                                 HALTE MUSEUM ACEH
# 3          3          2                                HALTE GUNONGAN (1)
# 4          3          3       HALTE GUNONGAN (2) (Depan Kuburan Kierkoff)
# 5          3          4                                    HALTE SEULAWAH
# 6          3          5                             HALTE PASAR SETUI (1)
# 7          3          6                             HALTE PASAR SETUI (2)
# 8          3          7    HALTE TEUKU UMAR (1) (Depan Masjid Teuku Umar)
# 9          3          8        HALTE TEUKU UMAR (2) (Samping Suzuya Mall)
# 10         3          9              HALTE GEUCEU (1) (Depan RS. Fakinah)
# 11         3         10           HALTE GEUCEU (2) (Seberang RS. Fakinah)
# 12         3         11  HALTE ASRAMA TNI (1) (Depan Zidam Iskandar Muda)
# 13         3         12   HALTE ASRAMA TNI (2) (Depan Asrama Perwira TNI)
# 14         3         13                   HALTE KEUTAPANG (1) (Depan KFC)
# 15         3         14           HALTE KETAPANG (2) (Depan Bank Mandiri)
# 16         3         15                                    HALTE TVRI (1)
# 17         3         16                                    HALTE TVRI (2)
# 18         3         17    HALTE MUHAMMADIYAH (Depan Masjid Muhammadiyah)
# 19         3         18              HALTE  MATA IE (Depan Kolam Mata Ie)
# 20         3         19                                    HALTE PORTABLE
#
#    Unnamed: 2           Unnamed: 3 TAHUN PEMBANGUNAN
# 0        NAMA            KOORDINAT               NaN
# 1         NaN                  NaN    (rencana awal)
# 2         NaN  5.549426, 95.320457         APBA 2017
# 3         NaN  5.545646, 95.315278         APBA 2017
# 4         NaN  5.546060, 95.315273         APBA 2017
# 5         NaN  5.541205, 95.310541         APBA 2017
# 6         NaN  5.539242, 95.309068         APBA 2017
# 7         NaN  5.539675, 95.309062         APBA 2017
# 8         NaN  5.537549, 95.307415         APBA 2017
# 9         NaN  5.538168, 95.307633         APBA 2017
# 10        NaN  5.529809, 95.303627         APBA 2017
# 11        NaN  5.530125, 95.303501         APBA 2017
# 12        NaN  5.523261, 95.302630         APBA 2017
# 13        NaN  5.523320, 95.302452         APBA 2017
# 14        NaN  5.517501, 95.303551         APBA 2017
# 15        NaN  5.514303, 95.303392         APBA 2017
# 16        NaN  5.508944, 95.303334         APBA 2017
# 17        NaN  5.508934, 95.303205         APBA 2017
# 18        NaN  5.553305, 95.314040         APBA 2017
# 19        NaN  5.496592, 95.296385         APBA 2017
# 20        NaN        sesuai demand         APBA 2017

# %%
# Remove unused row
# the last bus stop (index=20) will be deleted, because is not yet available, listed as on-demand ("sesuai demand" in bahasa)
corr3.drop(index=[0, 1, 20], inplace=True)

# Remove unused column
corr3.drop(columns=['Unnamed: 0', 'Unnamed: 2', 'TAHUN PEMBANGUNAN'], inplace=True)

# Rename the rest
corr3.rename(columns={'Unnamed: 1' : 'Name', 'Unnamed: 3' : 'Coordinates' }, inplace=True)
corr3.head()
# Out:
#    Corridor                                         Name          Coordinates
# 2         3                            HALTE MUSEUM ACEH  5.549426, 95.320457
# 3         3                           HALTE GUNONGAN (1)  5.545646, 95.315278
# 4         3  HALTE GUNONGAN (2) (Depan Kuburan Kierkoff)  5.546060, 95.315273
# 5         3                               HALTE SEULAWAH  5.541205, 95.310541
# 6         3                        HALTE PASAR SETUI (1)  5.539242, 95.309068

# %%
# Extract latitude and longitude
corr3['Latitude'] = corr3.Coordinates.str[:8]
corr3['Longtude'] = corr3.Coordinates.str[10:]
corr3.head()
# Out:
#    Corridor                                         Name          Coordinates  \
# 2         3                            HALTE MUSEUM ACEH  5.549426, 95.320457
# 3         3                           HALTE GUNONGAN (1)  5.545646, 95.315278
# 4         3  HALTE GUNONGAN (2) (Depan Kuburan Kierkoff)  5.546060, 95.315273
# 5         3                               HALTE SEULAWAH  5.541205, 95.310541
# 6         3                        HALTE PASAR SETUI (1)  5.539242, 95.309068
#
#    Latitude   Longtude
# 2  5.549426  95.320457
# 3  5.545646  95.315278
# 4  5.546060  95.315273
# 5  5.541205  95.310541
# 6  5.539242  95.309068

# %%
# Remove Coordinates column
corr3.drop(columns=['Coordinates'], inplace=True)
corr3
# Out:
#     Corridor                                              Name  Latitude  \
# 2          3                                 HALTE MUSEUM ACEH  5.549426
# 3          3                                HALTE GUNONGAN (1)  5.545646
# 4          3       HALTE GUNONGAN (2) (Depan Kuburan Kierkoff)  5.546060
# 5          3                                    HALTE SEULAWAH  5.541205
# 6          3                             HALTE PASAR SETUI (1)  5.539242
# 7          3                             HALTE PASAR SETUI (2)  5.539675
# 8          3    HALTE TEUKU UMAR (1) (Depan Masjid Teuku Umar)  5.537549
# 9          3        HALTE TEUKU UMAR (2) (Samping Suzuya Mall)  5.538168
# 10         3              HALTE GEUCEU (1) (Depan RS. Fakinah)  5.529809
# 11         3           HALTE GEUCEU (2) (Seberang RS. Fakinah)  5.530125
# 12         3  HALTE ASRAMA TNI (1) (Depan Zidam Iskandar Muda)  5.523261
# 13         3   HALTE ASRAMA TNI (2) (Depan Asrama Perwira TNI)  5.523320
# 14         3                   HALTE KEUTAPANG (1) (Depan KFC)  5.517501
# 15         3           HALTE KETAPANG (2) (Depan Bank Mandiri)  5.514303
# 16         3                                    HALTE TVRI (1)  5.508944
# 17         3                                    HALTE TVRI (2)  5.508934
# 18         3    HALTE MUHAMMADIYAH (Depan Masjid Muhammadiyah)  5.553305
# 19         3              HALTE  MATA IE (Depan Kolam Mata Ie)  5.496592
#
#      Longtude
# 2   95.320457
# 3   95.315278
# 4   95.315273
# 5   95.310541
# 6   95.309068
# 7   95.309062
# 8   95.307415
# 9   95.307633
# 10  95.303627
# 11  95.303501
# 12  95.302630
# 13  95.302452
# 14  95.303551
# 15  95.303392
# 16  95.303334
# 17  95.303205
# 18  95.314040
# 19  95.296385

# %% [markdown]
# ## Table 4

# %%
# extracting table
corr4 = pd.DataFrame(list[3][0])

# Corridor 4 : City Center-Ulee Kareng - Blang Bintang Route
corr4.insert(0, 'Corridor', 4)
corr4
# Out:
#     Corridor Unnamed: 0                                         Unnamed: 1  \
# 0          4         NO                                               NAMA
# 1          4        NaN                                                NaN
# 2          4          1                  HALTE KESDAM 1 (Depan RS. Kesdam)
# 3          4          2                  HALTE KESDAM 2 (Depan Kantor Pos)
# 4          4          3        HALTE KUTA ALAM 1 (Depan Masjid Babuttaqwa)
# 5          4          4               HALTE KUTA ALAM 2 (Depan Asrama TNI)
# 6          4          5              HALTE HERMES 1 (Depan Rumah Cut Zein)
# 7          4          6                                     HALTE HERMES 2
# 8          4          7                                       HALTE BPKP 1
# 9          4          8                 HALTE BPKP 2 (Depan Panglong Kayu)
# 10         4          9                                    HALTE SD 56 (1)
# 11         4         10                                    HALTE SD 56 (2)
# 12         4         11           HALTE ULEE KARENG 1 (Depan Gudang Donya)
# 13         4         12        HALTE ULEE KARENG 2 (Masjid  Baitussalihin)
# 14         4         13         HALTE BABUSSALAM 1 (Depan Masjid As Syifa)
# 15         4         14         HALTE BABUSSALAM 2 (Lewat Masjid As Syifa)
# 16         4         15                                 HALTE ABULYATAMA 1
# 17         4         16   HALTE ABULYATAMA 2 (Depan Pasantren Baitussabri)
# 18         4         17          HALTE LAM ATEUK 1 (Lewat Dayah Lam Ateuk)
# 19         4         18          HALTE LAM ATEUK 2 (Smpng Dayah Lam Ateuk)
# 20         4         19           HALTE BUENG CALA 1 (Depan SD Bueng Cala)
# 21         4         20  HALTE BUENG CALA 2 (Depan Komplek Rumah Perhub...
# 22         4         21                              HALTE BLANG BINTANG 1
# 23         4         22                              HALTE BLANG BINTANG 2
# 24         4         23                                     HALTE PORTABLE
#
#              Unnamed: 2 TAHUN PEMBANGUNAN
# 0             KOORDINAT               NaN
# 1                   NaN    (rencana awal)
# 2   5.555050, 95.324288         APBA 2017
# 3   5.555414, 95.325603         APBA 2017
# 4   5.554665, 95.329638         APBA 2017
# 5   5.554686, 95.329473         APBA 2017
# 6   5.553984, 95.332866         APBA 2017
# 7   5.553875, 95.332354         APBA 2017
# 8   5.553621, 95.343309         APBA 2017
# 9   5.553429, 95.343173         APBA 2017
# 10  5.551848, 95.352067         APBA 2017
# 11  5.551666, 95.352448         APBA 2017
# 12  5.551641, 95.354870         APBA 2017
# 13  5.551371, 95.355865         APBA 2017
# 14  5.546598, 95.362810         APBA 2017
# 15  5.544462, 95.365203         APBA 2017
# 16  5.531089, 95.387730         APBA 2017
# 17  5.530865, 95.388305         APBA 2017
# 18  5.532918, 95.393197         APBA 2017
# 19  5.531700, 95.391097         APBA 2017
# 20  5.528145, 95.407072         APBA 2017
# 21  5.526318, 95.401094         APBA 2017
# 22  5.525412, 95.414448         APBA 2017
# 23  5.525502, 95.414161         APBA 2017
# 24        sesuai demand         APBA 2017

# %%
# Remove unused row
# the last bus stop (index=24) will be deleted, because is not yet available, listed as on-demand ("sesuai demand" in bahasa)
corr4.drop(index=[0, 1, 24], inplace=True)

# Remove unused column
corr4.drop(columns=['Unnamed: 0', 'TAHUN PEMBANGUNAN'], inplace=True)

# Rename the rest
corr4.rename(columns={'Unnamed: 1' : 'Name', 'Unnamed: 2' : 'Coordinates' }, inplace=True)
corr4.head()
# Out:
#    Corridor                                         Name          Coordinates
# 2         4            HALTE KESDAM 1 (Depan RS. Kesdam)  5.555050, 95.324288
# 3         4            HALTE KESDAM 2 (Depan Kantor Pos)  5.555414, 95.325603
# 4         4  HALTE KUTA ALAM 1 (Depan Masjid Babuttaqwa)  5.554665, 95.329638
# 5         4         HALTE KUTA ALAM 2 (Depan Asrama TNI)  5.554686, 95.329473
# 6         4        HALTE HERMES 1 (Depan Rumah Cut Zein)  5.553984, 95.332866

# %%
# Extract latitude and longitude
corr4['Latitude'] = corr4.Coordinates.str[:8]
corr4['Longtude'] = corr4.Coordinates.str[10:]
corr4.head()
# Out:
#    Corridor                                         Name          Coordinates  \
# 2         4            HALTE KESDAM 1 (Depan RS. Kesdam)  5.555050, 95.324288
# 3         4            HALTE KESDAM 2 (Depan Kantor Pos)  5.555414, 95.325603
# 4         4  HALTE KUTA ALAM 1 (Depan Masjid Babuttaqwa)  5.554665, 95.329638
# 5         4         HALTE KUTA ALAM 2 (Depan Asrama TNI)  5.554686, 95.329473
# 6         4        HALTE HERMES 1 (Depan Rumah Cut Zein)  5.553984, 95.332866
#
#    Latitude   Longtude
# 2  5.555050  95.324288
# 3  5.555414  95.325603
# 4  5.554665  95.329638
# 5  5.554686  95.329473
# 6  5.553984  95.332866

# %%
# Remove Coordinates column
corr4.drop(columns=['Coordinates'], inplace=True)
corr4
# Out:
#     Corridor                                               Name  Latitude  \
# 2          4                  HALTE KESDAM 1 (Depan RS. Kesdam)  5.555050
# 3          4                  HALTE KESDAM 2 (Depan Kantor Pos)  5.555414
# 4          4        HALTE KUTA ALAM 1 (Depan Masjid Babuttaqwa)  5.554665
# 5          4               HALTE KUTA ALAM 2 (Depan Asrama TNI)  5.554686
# 6          4              HALTE HERMES 1 (Depan Rumah Cut Zein)  5.553984
# 7          4                                     HALTE HERMES 2  5.553875
# 8          4                                       HALTE BPKP 1  5.553621
# 9          4                 HALTE BPKP 2 (Depan Panglong Kayu)  5.553429
# 10         4                                    HALTE SD 56 (1)  5.551848
# 11         4                                    HALTE SD 56 (2)  5.551666
# 12         4           HALTE ULEE KARENG 1 (Depan Gudang Donya)  5.551641
# 13         4        HALTE ULEE KARENG 2 (Masjid  Baitussalihin)  5.551371
# 14         4         HALTE BABUSSALAM 1 (Depan Masjid As Syifa)  5.546598
# 15         4         HALTE BABUSSALAM 2 (Lewat Masjid As Syifa)  5.544462
# 16         4                                 HALTE ABULYATAMA 1  5.531089
# 17         4   HALTE ABULYATAMA 2 (Depan Pasantren Baitussabri)  5.530865
# 18         4          HALTE LAM ATEUK 1 (Lewat Dayah Lam Ateuk)  5.532918
# 19         4          HALTE LAM ATEUK 2 (Smpng Dayah Lam Ateuk)  5.531700
# 20         4           HALTE BUENG CALA 1 (Depan SD Bueng Cala)  5.528145
# 21         4  HALTE BUENG CALA 2 (Depan Komplek Rumah Perhub...  5.526318
# 22         4                              HALTE BLANG BINTANG 1  5.525412
# 23         4                              HALTE BLANG BINTANG 2  5.525502
#
#      Longtude
# 2   95.324288
# 3   95.325603
# 4   95.329638
# 5   95.329473
# 6   95.332866
# 7   95.332354
# 8   95.343309
# 9   95.343173
# 10  95.352067
# 11  95.352448
# 12  95.354870
# 13  95.355865
# 14  95.362810
# 15  95.365203
# 16  95.387730
# 17  95.388305
# 18  95.393197
# 19  95.391097
# 20  95.407072
# 21  95.401094
# 22  95.414448
# 23  95.414161
